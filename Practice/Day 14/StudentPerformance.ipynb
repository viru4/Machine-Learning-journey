# %% [markdown]
# Train a Decision Tree to predict:
#
# 📌 Whether a student passes exam
#
# Features:
#
# Study Hours	Attendance	Pass
# 2	             Low	No
# 4	           Medium	Yes
# 6	            High	Yes
# 1	             Low	No
# 5	            High	Yes
#
# Tasks:
# Encode data
#
# Train tree using entropy
#
# Predict for:
#
# 👉 Study = 3
# 👉 Attendance = Medium

# %%
import pandas as pd
import numpy as np

# %%
# Dataset
data = {
    'Study': [2, 4, 6, 1, 5],
    'Attendance': ['Low', 'Medium', 'High', 'Low', 'High'],
    'Pass': ['No', 'Yes', 'Yes', 'No', 'Yes']
}
df=pd.DataFrame(data)

# %%
# encoding categorical features like attendence and pass
from sklearn.preprocessing import LabelEncoder

le_att=LabelEncoder()
le_pass= LabelEncoder()
